# %%
# Sample Data
data = [(1, 100, 'aa'), (2, 200, 'bb'), (3, 300, 'cc')]

# Create a Spark DataFrame
df = spark.createDataFrame(data, ['id', 'salary', 'name'])

display(df)

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/deltalake/default/deltavol/demosink/")

# %%
df = spark.read.format("json")\
            .load("/Volumes/deltalake/default/deltavol/demosink/_delta_log/00000000000000000000.json")
display(df)
