# %% [markdown]
# ## TABLE UTILITY COMMANDS

# %%
# %sql
DESCRIBE deltalake.default.first_table

# %%
# %sql
DESCRIBE DETAIL deltalake.default.first_table

# %%
# %sql
DESCRIBE EXTENDED deltalake.default.first_table

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/deltalake/default/deltavol/demosink/`

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/deltalake/default/deltavol/demosink/`
